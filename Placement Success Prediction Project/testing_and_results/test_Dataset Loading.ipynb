# %%
# Step 1: Import the required library
import pandas as pd

# Step 2: Define the path to your CSV file
# Replace 'your_dataset.csv' with your actual file name or file path
file_path = "your_dataset.csv"

# Step 3: Load the first 100 records of the dataset
# Using nrows optimizes memory by only reading the required rows
df = pd.read_csv(r"E:\sanket major MSDS\PlacementSuccessPredictionProject\data\student_placement_career_success_dataset_2026.csv", nrows=100)

# Step 4: Display the loaded data
# pd.set_option ensures you can see all 100 rows in the notebook output
pd.set_option("display.max_rows", 100)
df
# Out:
#     Age  Gender College_Tier          Specialization  CGPA  \
# 0    19    Male       Tier 3                   AI/ML  7.70
# 1    21   Other       Tier 3                   Civil  6.97
# 2    20   Other       Tier 2             Electronics  6.74
# 3    18   Other       Tier 2        Computer Science  6.64
# 4    18   Other       Tier 2             Electronics  8.67
# 5    21   Other       Tier 2  Information Technology  7.31
# 6    23    Male       Tier 2        Computer Science  6.60
# 7    20  Female       Tier 1  Information Technology  5.98
# 8    25    Male       Tier 3            Data Science  7.94
# 9    22   Other       Tier 3        Computer Science  6.48
# 10   25    Male       Tier 3  Information Technology  7.52
# 11   23    Male       Tier 2            Data Science  8.13
# 12   21    Male       Tier 2                   Civil  6.72
# 13   20  Female       Tier 2                   Civil  8.56
# 14   19    Male       Tier 2             Electronics  7.56
# ...
